# %% [markdown]
# ## Урок 4

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# $$M(X) = \frac{a + b}{2}$$

# %%
(200 + 800) / 2
# Out:
# 500.0

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12}$$

# %%
(800 - 200) ** 2 / 12
# Out:
# 30000.0

# %% [markdown]
# ### Задача 2

# %% [markdown]
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12}$$

# %% [markdown]
# $$b = \sqrt{12D}{ + a}$$

# %%
((12 * 0.2) ** (1/2)) + 0.5
# Out:
# 2.049193338482967

# %% [markdown]
# $$M(X) = \frac{a + b}{2}$$

# %%
(0.5 + 2.05) / 2
# Out:
# 1.275

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$

# %% [markdown]
# $$f(x) = \frac{1}{4 \sqrt{2 \pi}} e ^ {- \frac{(x + 2)^2}{32}},$$

# %% [markdown]
# M(X) = - 2 <br>
# D(X) = 16 <br>
# std(X) = 4

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %% [markdown]
# ![slide-4.jpg](attachment:slide-4.jpg)

# %% [markdown]
# <b>а). больше 182 см.

# %%
13.6 + 2.1 + 0.1
# Out:
# 15.799999999999999

# %%
1 - norm.cdf(1)
# Out:
# 0.15865525393145707

# %% [markdown]
# <b>б). больше 190 см.

# %%
2.1 + 0.1
# Out:
# 2.2

# %%
1 - norm.cdf(2)
# Out:
# 0.02275013194817921

# %% [markdown]
# <b>в). от 166 см до 190 см.

# %%
68.2 + 13.6
# Out:
# 81.8

# %%
norm.cdf(2) - norm.cdf(-1)
# Out:
# 0.8185946141203637

# %% [markdown]
# <b>г). от 166 см до 182 см.

# %%
68.2
# Out:
# 68.2

# %%
norm.cdf(1) - norm.cdf(-1)
# Out:
# 0.6826894921370859

# %% [markdown]
# <b>д). от 158 см до 190 см.

# %%
95.4
# Out:
# 95.4

# %%
norm.cdf(2) - norm.cdf(-2)
# Out:
# 0.9544997361036416

# %% [markdown]
# <b>е). не выше 150 см или не ниже 190 см.

# %%
0.1 + 2.1 + 0.1
# Out:
# 2.3000000000000003

# %%
(norm.cdf(3) - norm.cdf(2)) + norm.cdf(-3)
# Out:
# 0.022750131948179198

# %% [markdown]
# <b>ё). не выше 150 см или не ниже 198 см.

# %%
0.1 + 0.1
# Out:
# 0.2

# %%
(1 - norm.cdf(3)) + norm.cdf(-3)
# Out:
# 0.0026997960632601965

# %% [markdown]
# <b>ж). ниже 166 см.

# %%
13.6 + 2.1 + 0.1
# Out:
# 15.799999999999999

# %%
norm.cdf(-1)
# Out:
# 0.15865525393145707

# %% [markdown]
# ### Задача 5

# %% [markdown]
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
std = 5
(190 - 178)/5
# Out:
# 2.4
